# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image 
from tensorflow.keras.layers import Layer 
from tensorflow import keras

model_path = r"eurosat_rgb_model.h5"
# model = tf.keras.models.load_model(model_path)
model = keras.models.load_model(model_path)

class_names = [
    'AnnualCrop', 'Forest', 'HerbaceousVegetation', 'Highway',
    'Industrial', 'Pasture', 'PermanentCrop', 'Residential',
    'River', 'SeaLake'
]

# %%
def pred_and_plot_image(model, image_path, class_names):
    img = image.load_img(image_path, target_size=(64, 64))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = img_array / 255.0  

    predictions = model.predict(img_array)
    predicted_class = class_names[np.argmax(predictions)]
    confidence = np.max(predictions)

    plt.imshow(img)
    plt.axis("off")
    plt.title(f"Predicted: {predicted_class} ({confidence:.2f})")
    plt.show()

    return predicted_class, confidence

# %%
custom_image_path = r'agri1.jpg'

pred_and_plot_image(model, custom_image_path, class_names)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# ('PermanentCrop', np.float32(0.99922323))
